# %%
import pandas as pd

df = pd.read_csv('../data/dataset.csv')
df.head()

# %%
df.describe()

# %%
df[df['risk_score'] > 70]

# %%
import matplotlib.pyplot as plt

df['risk_score'].hist()
plt.title("Risk Score Distribution")
plt.show()
